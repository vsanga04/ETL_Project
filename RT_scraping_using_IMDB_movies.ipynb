# %% [markdown]
# IMDB scraping using RT top 100 movie list

# %%
import pandas as pd

# %%
df_imdb = pd.read_csv('IMDB_ratings.csv')
df_imdb
# Out:
#     Unnamed: 0                     Movie  IMDB Score
# 0            0  The Shawshank Redemption         9.3
# 1            1             The Godfather         9.2
# 2            2           The Dark Knight         9.0
# 3            3    The Godfather: Part II         9.0
# 4            4              12 Angry Men         9.0
# ..         ...                       ...         ...
# 95          95        North by Northwest         8.3
# 96          96                   Vertigo         8.3
# 97          97       Singin' in the Rain         8.3
# 98          98              Citizen Kane         8.3
# 99          99                         M         8.3
#
# [100 rows x 3 columns]

# %%
movie_names = df_imdb['Movie'].to_list()
movie_names
# Out:
# ['The Shawshank Redemption',
#  'The Godfather',
#  'The Dark Knight',
#  'The Godfather: Part II',
#  '12 Angry Men',
#  'The Lord of the Rings: The Return of the King',
#  'Pulp Fiction',
#  "Schindler's List",
#  'Inception',
#  'Fight Club',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'Forrest Gump',
#  'The Good, the Bad and the Ugly',
#  'The Lord of the Rings: The Two Towers',
#  'The Matrix',
#  'Goodfellas',
#  'Star Wars: Episode V - The Empire Strikes Back',
#  "One Flew Over the Cuckoo's Nest",
#  'Parasite',
#  'Interstellar',
#  'City of God',
#  'Spirited Away',
#  'Saving Private Ryan',
#  'The Green Mile',
#  'Life Is Beautiful',
#  'Se7en',
#  'The Silence of the Lambs',
#  'Star Wars: Episode IV - A New Hope',
#  'Hara-Kiri',
#  'Pather Panchali',
#  'Seven Samurai',
#  "It's a Wonderful Life",
#  'Hamilton',
#  'Whiplash',
#  'The Intouchables',
#  'The Prestige',
#  'The Departed',
#  'The Pianist',
#  'Gladiator',
#  'American History X',
# ...

# %%
records = df_imdb["Movie"]

records = [[rec.replace(' ', '%20')] for rec in records]

records
# Out:
# [['The%20Shawshank%20Redemption'],
#  ['The%20Godfather'],
#  ['The%20Dark%20Knight'],
#  ['The%20Godfather:%20Part%20II'],
#  ['12%20Angry%20Men'],
#  ['The%20Lord%20of%20the%20Rings:%20The%20Return%20of%20the%20King'],
#  ['Pulp%20Fiction'],
#  ["Schindler's%20List"],
#  ['Inception'],
#  ['Fight%20Club'],
#  ['The%20Lord%20of%20the%20Rings:%20The%20Fellowship%20of%20the%20Ring'],
#  ['Forrest%20Gump'],
#  ['The%20Good,%20the%20Bad%20and%20the%20Ugly'],
#  ['The%20Lord%20of%20the%20Rings:%20The%20Two%20Towers'],
#  ['The%20Matrix'],
#  ['Goodfellas'],
#  ['Star%20Wars:%20Episode%20V%20-%20The%20Empire%20Strikes%20Back'],
#  ["One%20Flew%20Over%20the%20Cuckoo's%20Nest"],
#  ['Parasite'],
#  ['Interstellar'],
#  ['City%20of%20God'],
#  ['Spirited%20Away'],
#  ['Saving%20Private%20Ryan'],
#  ['The%20Green%20Mile'],
#  ['Life%20Is%20Beautiful'],
#  ['Se7en'],
#  ['The%20Silence%20of%20the%20Lambs'],
#  ['Star%20Wars:%20Episode%20IV%20-%20A%20New%20Hope'],
#  ['Hara-Kiri'],
# ...

# %%
from splinter import Browser
from bs4 import BeautifulSoup as bs
import time
from webdriver_manager.chrome import ChromeDriverManager
import requests

# def scrape_rt_score(movie):
#     executable_path = {'executable_path': ChromeDriverManager().install()}
#     browser = Browser('chrome', **executable_path, headless=False)
    
#     movie_records = records
#     url = f"https://www.rottentomatoes.com/search?search={movie_records}/"
# #     browser.visit(url)
#     response = requests.get(url)
#     soup = bs(response.text, "html.parser")
#     movie  = soup.find("h2", class_ = "Title").text

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
    
url = f"https://www.rottentomatoes.com/search?search=titanic/"
browser.visit(url)
html = browser.html
soup = bs(html, "html.parser")
movie = soup.find("h2", class_ = "title").get_text()
# movie  = soup.find('div', attrs={'class':'mop-ratings-wrap__half'}")
    
movie
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [C:\Users\17076\.wdm\drivers\chromedriver\win32\91.0.4472.19\chromedriver.exe] found in cache
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-5ad675d95b82> in <module>
#       6 html = browser.html
#       7 soup = bs(html, "html.parser")
# ----> 8 movie = soup.find("h2", class_ = "title").get_text()
#       9 # movie  = soup.find('div', attrs={'class':'mop-ratings-wrap__half'}")
#      10
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
soup

# %%
df_imdb["RT_score"] = [scrape_rt_score(movie) for movie in records]
df_imdb
