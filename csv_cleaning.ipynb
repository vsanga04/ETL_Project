# %%
import pandas as pd

# %%
df_imdb = pd.read_csv('IMDB_ratings.csv')
df_imdb.head()
# Out:
#    Unnamed: 0                     Movie  IMDB Score
# 0           0  The Shawshank Redemption         9.3
# 1           1             The Godfather         9.2
# 2           2           The Dark Knight         9.0
# 3           3    The Godfather: Part II         9.0
# 4           4              12 Angry Men         9.0

# %%
df_rt = pd.read_csv('RT_ratings.csv')
df_rt.head()
# Out:
#    Unnamed: 0 RatingTomatometer                  Title
# 0           0               99%  It Happened One Night
# 1           1               98%           Modern Times
# 2           2               96%          Black Panther
# 3           3               99%       The Wizard of Oz
# 4           4               99%           Citizen Kane

# %%
merged = pd.merge(df_imdb, df_rt, how = "outer", left_on="Movie", right_on="Title")
merged
# Out:
#      Unnamed: 0_x                     Movie  IMDB Score  Unnamed: 0_y  \
# 0             0.0  The Shawshank Redemption         9.3           NaN
# 1             1.0             The Godfather         9.2          16.0
# 2             2.0           The Dark Knight         9.0           NaN
# 3             3.0    The Godfather: Part II         9.0           NaN
# 4             4.0              12 Angry Men         9.0           NaN
# ..            ...                       ...         ...           ...
# 181           NaN                       NaN         NaN          93.0
# 182           NaN                       NaN         NaN          95.0
# 183           NaN                       NaN         NaN          96.0
# 184           NaN                       NaN         NaN          98.0
# 185           NaN                       NaN         NaN          99.0
#
#     RatingTomatometer                           Title
# 0                 NaN                             NaN
# ...

# %%
merged.query('Movie != Title')
# Out:
#      Unnamed: 0_x                                          Movie  IMDB Score  \
# 0             0.0                       The Shawshank Redemption         9.3
# 2             2.0                                The Dark Knight         9.0
# 3             3.0                         The Godfather: Part II         9.0
# 4             4.0                                   12 Angry Men         9.0
# 5             5.0  The Lord of the Rings: The Return of the King         8.9
# ..            ...                                            ...         ...
# 181           NaN                                            NaN         NaN
# 182           NaN                                            NaN         NaN
# 183           NaN                                            NaN         NaN
# 184           NaN                                            NaN         NaN
# 185           NaN                                            NaN         NaN
#
# ...
